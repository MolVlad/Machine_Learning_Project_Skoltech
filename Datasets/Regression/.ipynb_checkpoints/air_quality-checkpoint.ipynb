# %%
import pandas as pd
import numpy as np
#https://archive.ics.uci.edu/ml/datasets/Air+Quality

# %%
df=pd.read_csv("air_quality_done.csv")

# %%
df
# Out:
#      CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0       2.6      1360.00     150.0  11.881723        1045.50    166.0
# 1       2.0      1292.25     112.0   9.397165         954.75    103.0
# 2       2.2      1402.00      88.0   8.997817         939.25    131.0
# 3       2.2      1375.50      80.0   9.228796         948.25    172.0
# 4       1.6      1272.25      51.0   6.518224         835.50    131.0
# ..      ...          ...       ...        ...            ...      ...
# 822     4.4      1449.25     501.0  19.494597        1282.25    254.0
# 823     3.1      1362.50     234.0  15.100351        1151.75    189.0
# 824     3.0      1371.25     212.0  14.594739        1135.75    174.0
# 825     3.1      1406.25     275.0  13.697100        1106.75    167.0
# 826     3.5      1424.50     275.0  15.187992        1154.50    185.0
#
#      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T         RH  \
# ...
