# %%
import pandas as pd
import numpy as np
#https://archive.ics.uci.edu/ml/datasets/SkillCraft1+Master+Table+Dataset#

# %%
df=pd.read_csv("skill_craft1_done.csv")

# %%
df
# Out:
#       LeagueIndex  Age  HoursPerWeek  TotalHours       APM  SelectByHotkeys  \
# 0               5   27            10        3000  143.7180         0.003515
# 1               5   23            10        5000  129.2322         0.003304
# 2               4   30            10         200   69.9612         0.001101
# 3               3   19            20         400  107.6016         0.001034
# 4               3   32            10         500  122.8908         0.001136
# ...           ...  ...           ...         ...       ...              ...
# 3333            4   20             8         400  158.1390         0.013829
# 3334            5   16            56        1500  186.1320         0.006951
# 3335            4   21             8         100  121.6992         0.002956
# 3336            3   20            28         400  134.2848         0.005424
# 3337            4   22             6         400   88.8246         0.000844
#
# ...
